# %%
import gymnasium as gym
import numpy as np 
import matplotlib.pyplot as plt
import random

# %%
#monte carlo update with complete average or expectation
env = gym.make("FrozenLake-v1", is_slippery=True, render_mode=None)

#hyper parameters
num_episodes = 100000 #num of epi to train
gamma = 0.99
epsilon_start = 1.0
epsilon_end = 0.01
epsilon_decay = 0.00001
stepsize_alpha = 0.1 

num_states = env.observation_space.n
num_actions = env.action_space.n

#action value matrix
Q = np.zeros((num_states, num_actions))
Policy = np.zeros((num_states))
return_count = np.zeros((num_states, num_actions))

def epsilon_greedy_policy(state, Q, epsilon):
    if random.uniform(0, 1) < epsilon: #explore
        return env.action_space.sample() 
    
    else:
        return np.argmax(Q[state]) #choose greddy
    
for i_episode in range(1, num_episodes + 1):
    episode = [] #to save current episode history
    state, info = env.reset()
    terminated = False
    truncated = False

    #Epsilon decay
    epsilon = max(epsilon_end, epsilon_start - epsilon_decay*i_episode)

    while (not terminated and not truncated):
        action = epsilon_greedy_policy(state, Q, epsilon)
        next_state, reward, terminated, truncated, info = env.step(action)

        #store the state, action, reward
        episode.append((state, action, reward))

        state = next_state

    #monte carlo update
    G = 0 #total return for current episode

    for t in reversed(range(len(episode))):
        state_t, action_t, reward_t = episode[t]

        #update the total retunr
        G = reward_t + gamma * G

        #for every visit counter
        return_count[state_t][action_t] += 1.0

        #update Q values
        current_Q = Q[state_t][action_t]
        Q[state_t][action_t] = current_Q + (1/return_count[state_t][action_t]) * (G - current_Q)
        #Q[state_t][action_t] = current_Q + (stepsize_alpha) * (G - current_Q)

    #progress report
    if i_episode % 1000 == 0:
        print(f"\nEpisode {i_episode}/{num_episodes}, Epsilon: {epsilon:.4f}")    

        Policy = np.argmax(Q, axis=1)

        #Evaluate the learned policy
        print("Evaluating learned policy...")
        total_rewards = 0
        num_eval_episodes = 100

        for _ in range(num_eval_episodes):
            state, info = env.reset()
            terminated = False
            truncated = False
            episode_reward = 0
            while (not terminated and not truncated):
                # For evaluation, use a greedy policy (no exploration)
                action = Policy[state]
                next_state, reward, done, truncated, info = env.step(action)
                episode_reward += reward
                state = next_state

            total_rewards += episode_reward

        print(f"Average reward over {num_eval_episodes} evaluation episodes: {total_rewards / num_eval_episodes:.4f}")
        print("the best policy \n", Policy.reshape(4,4))

env.close()
#best policy
Policy = np.argmax(Q, axis=1)
print("the best policy: ", Policy)
# Out:
# Episode 1000/100000, Epsilon: 0.9900
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2400
# the best policy
#  [[0 1 2 0]
#  [0 0 1 0]
#  [3 2 1 0]
#  [0 1 2 0]]
#
# Episode 2000/100000, Epsilon: 0.9800
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.1600
# the best policy
#  [[0 1 2 0]
#  [0 0 1 0]
#  [3 2 1 0]
#  [0 1 2 0]]
#
# Episode 3000/100000, Epsilon: 0.9700
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.0500
# the best policy
#  [[2 1 2 0]
#  [0 0 1 0]
#  [3 2 1 0]
#  [0 2 2 0]]
#
# Episode 4000/100000, Epsilon: 0.9600
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.1600
# the best policy
#  [[1 1 2 0]
#  [0 0 1 0]
#  [3 1 1 0]
#  [0 2 2 0]]
#
# Episode 5000/100000, Epsilon: 0.9500
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2600
# the best policy
#  [[2 1 2 0]
#  [0 0 1 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 6000/100000, Epsilon: 0.9400
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.1000
# the best policy
#  [[3 1 2 3]
#  [0 0 1 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 7000/100000, Epsilon: 0.9300
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.6200
# the best policy
#  [[0 1 2 3]
#  [0 0 1 0]
#  [3 1 1 0]
#  [0 2 1 0]]
#
# Episode 8000/100000, Epsilon: 0.9200
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.0800
# the best policy
#  [[3 1 2 3]
#  [0 0 1 0]
#  [3 1 1 0]
#  [0 2 2 0]]
#
# Episode 9000/100000, Epsilon: 0.9100
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.0500
# the best policy
#  [[3 1 2 3]
#  [0 0 1 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 10000/100000, Epsilon: 0.9000
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.7100
# the best policy
#  [[0 1 2 3]
#  [0 0 1 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 11000/100000, Epsilon: 0.8900
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.5900
# the best policy
#  [[0 3 2 3]
#  [0 0 1 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 12000/100000, Epsilon: 0.8800
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.5900
# the best policy
#  [[0 1 2 3]
#  [0 0 1 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 13000/100000, Epsilon: 0.8700
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.0500
# the best policy
#  [[3 1 2 3]
#  [0 0 1 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 14000/100000, Epsilon: 0.8600
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.6900
# the best policy
#  [[0 1 1 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 15000/100000, Epsilon: 0.8500
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2200
# the best policy
#  [[3 3 1 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 16000/100000, Epsilon: 0.8400
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2800
# the best policy
#  [[3 3 2 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 17000/100000, Epsilon: 0.8300
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2600
# the best policy
#  [[3 3 2 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 18000/100000, Epsilon: 0.8200
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3100
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 19000/100000, Epsilon: 0.8100
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2700
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 20000/100000, Epsilon: 0.8000
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2900
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 21000/100000, Epsilon: 0.7900
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2700
# the best policy
#  [[3 3 2 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 22000/100000, Epsilon: 0.7800
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3500
# the best policy
#  [[2 3 2 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 23000/100000, Epsilon: 0.7700
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2500
# the best policy
#  [[3 3 2 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 24000/100000, Epsilon: 0.7600
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2500
# the best policy
#  [[3 3 2 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 25000/100000, Epsilon: 0.7500
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2400
# the best policy
#  [[3 3 2 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 26000/100000, Epsilon: 0.7400
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2700
# the best policy
#  [[3 3 2 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 27000/100000, Epsilon: 0.7300
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3000
# the best policy
#  [[3 3 2 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 28000/100000, Epsilon: 0.7200
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.1800
# the best policy
#  [[3 3 2 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 29000/100000, Epsilon: 0.7100
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2700
# the best policy
#  [[3 3 2 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 30000/100000, Epsilon: 0.7000
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2900
# the best policy
#  [[3 3 2 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 31000/100000, Epsilon: 0.6900
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2600
# the best policy
#  [[3 3 2 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 32000/100000, Epsilon: 0.6800
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2500
# the best policy
#  [[3 3 2 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 33000/100000, Epsilon: 0.6700
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2800
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 34000/100000, Epsilon: 0.6600
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2200
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 35000/100000, Epsilon: 0.6500
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2400
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 36000/100000, Epsilon: 0.6400
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3000
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 37000/100000, Epsilon: 0.6300
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.1800
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 38000/100000, Epsilon: 0.6200
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2700
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 39000/100000, Epsilon: 0.6100
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3000
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 40000/100000, Epsilon: 0.6000
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2600
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 41000/100000, Epsilon: 0.5900
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2700
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 42000/100000, Epsilon: 0.5800
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2900
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 43000/100000, Epsilon: 0.5700
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2500
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 44000/100000, Epsilon: 0.5600
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2600
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 45000/100000, Epsilon: 0.5500
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2600
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 46000/100000, Epsilon: 0.5400
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2400
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 47000/100000, Epsilon: 0.5300
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2300
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 48000/100000, Epsilon: 0.5200
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2300
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 49000/100000, Epsilon: 0.5100
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2600
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 50000/100000, Epsilon: 0.5000
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2400
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 51000/100000, Epsilon: 0.4900
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2500
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 52000/100000, Epsilon: 0.4800
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2100
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 53000/100000, Epsilon: 0.4700
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2200
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 54000/100000, Epsilon: 0.4600
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2000
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 55000/100000, Epsilon: 0.4500
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2000
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 56000/100000, Epsilon: 0.4400
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2500
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 57000/100000, Epsilon: 0.4300
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2000
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 58000/100000, Epsilon: 0.4200
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.1700
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 59000/100000, Epsilon: 0.4100
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2100
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 60000/100000, Epsilon: 0.4000
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2500
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 61000/100000, Epsilon: 0.3900
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2600
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 62000/100000, Epsilon: 0.3800
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2600
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 63000/100000, Epsilon: 0.3700
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2600
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 64000/100000, Epsilon: 0.3600
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3100
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 65000/100000, Epsilon: 0.3500
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.4000
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 66000/100000, Epsilon: 0.3400
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2500
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 67000/100000, Epsilon: 0.3300
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2500
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 68000/100000, Epsilon: 0.3200
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2200
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 69000/100000, Epsilon: 0.3100
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2300
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 70000/100000, Epsilon: 0.3000
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2700
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 71000/100000, Epsilon: 0.2900
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2400
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 72000/100000, Epsilon: 0.2800
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2200
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 73000/100000, Epsilon: 0.2700
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2500
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 74000/100000, Epsilon: 0.2600
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.1900
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 75000/100000, Epsilon: 0.2500
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2100
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 76000/100000, Epsilon: 0.2400
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2400
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 77000/100000, Epsilon: 0.2300
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3600
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 78000/100000, Epsilon: 0.2200
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2500
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 79000/100000, Epsilon: 0.2100
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2500
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 80000/100000, Epsilon: 0.2000
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2600
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 81000/100000, Epsilon: 0.1900
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3300
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 82000/100000, Epsilon: 0.1800
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2200
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 83000/100000, Epsilon: 0.1700
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3400
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 84000/100000, Epsilon: 0.1600
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2500
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 85000/100000, Epsilon: 0.1500
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2300
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 86000/100000, Epsilon: 0.1400
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2400
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 87000/100000, Epsilon: 0.1300
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2500
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 88000/100000, Epsilon: 0.1200
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2200
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 89000/100000, Epsilon: 0.1100
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.1900
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 90000/100000, Epsilon: 0.1000
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.1600
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 91000/100000, Epsilon: 0.0900
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2000
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 92000/100000, Epsilon: 0.0800
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3800
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 93000/100000, Epsilon: 0.0700
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.1900
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 94000/100000, Epsilon: 0.0600
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3700
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 95000/100000, Epsilon: 0.0500
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2700
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 96000/100000, Epsilon: 0.0400
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3200
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 97000/100000, Epsilon: 0.0300
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2100
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 98000/100000, Epsilon: 0.0200
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2400
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 99000/100000, Epsilon: 0.0100
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2600
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]
#
# Episode 100000/100000, Epsilon: 0.0100
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2000
# the best policy
#  [[3 3 2 3]
#  [0 0 2 0]
#  [3 1 0 0]
#  [0 2 2 0]]

# %%
#monte carlo update with fixed stepsize average
env = gym.make("FrozenLake-v1", is_slippery=True, render_mode=None)

#hyper parameters
num_episodes = 100000 #num of epi to train
gamma = 0.99
epsilon_start = 1.0
epsilon_end = 0.01
epsilon_decay = 0.00001
stepsize_alpha = 0.001 

num_states = env.observation_space.n
num_actions = env.action_space.n

#action value matrix
Q = np.zeros((num_states, num_actions))
Policy = np.zeros((num_states))
return_count = np.zeros((num_states, num_actions))

def epsilon_greedy_policy(state, Q, epsilon):
    if random.uniform(0, 1) < epsilon: #explore
        return env.action_space.sample() 
    
    else:
        return np.argmax(Q[state]) #choose greddy
    
for i_episode in range(1, num_episodes + 1):
    episode = [] #to save current episode history
    state, info = env.reset()
    terminated = False
    truncated = False

    #Epsilon decay
    epsilon = max(epsilon_end, epsilon_start - epsilon_decay*i_episode)

    while (not terminated and not truncated):
        action = epsilon_greedy_policy(state, Q, epsilon)
        next_state, reward, terminated, truncated, info = env.step(action)

        #store the state, action, reward
        episode.append((state, action, reward))

        state = next_state

    #monte carlo update
    G = 0 #total return for current episode

    for t in reversed(range(len(episode))):
        state_t, action_t, reward_t = episode[t]

        #update the total retunr
        G = reward_t + gamma * G

        #for every visit counter
        return_count[state_t][action_t] += 1.0

        #update Q values
        current_Q = Q[state_t][action_t]
        # Q[state_t][action_t] = current_Q + (1/return_count[state_t][action_t]) * (G - current_Q)
        Q[state_t][action_t] = current_Q + (stepsize_alpha) * (G - current_Q)

    #progress report
    if i_episode % 1000 == 0:
        print(f"\nEpisode {i_episode}/{num_episodes}, Epsilon: {epsilon:.4f}")    
        
        Policy = np.argmax(Q, axis=1)
        
        #Evaluate the learned policy
        print("Evaluating learned policy...")
        total_rewards = 0
        num_eval_episodes = 100

        for _ in range(num_eval_episodes):
            state, info = env.reset()
            terminated = False
            truncated = False
            episode_reward = 0
            while (not terminated and not truncated):
                # For evaluation, use a greedy policy (no exploration)
                action = Policy[state]
                next_state, reward, done, truncated, info = env.step(action)
                episode_reward += reward
                state = next_state

            total_rewards += episode_reward

        print(f"Average reward over {num_eval_episodes} evaluation episodes: {total_rewards / num_eval_episodes:.4f}")
        print("the best policy \n", Policy.reshape(4,4))

env.close()
#best policy
Policy = np.argmax(Q, axis=1)
print("the best policy: ", Policy)
# Out:
# Episode 1000/100000, Epsilon: 0.9900
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.1600
# the best policy
#  [[0 3 0 1]
#  [2 0 0 0]
#  [1 1 0 0]
#  [0 2 1 0]]
#
# Episode 2000/100000, Epsilon: 0.9800
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.1600
# the best policy
#  [[0 3 0 1]
#  [0 0 0 0]
#  [1 2 0 0]
#  [0 2 3 0]]
#
# Episode 3000/100000, Epsilon: 0.9700
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.1000
# the best policy
#  [[2 3 1 1]
#  [2 0 1 0]
#  [3 2 0 0]
#  [0 2 3 0]]
#
# Episode 4000/100000, Epsilon: 0.9600
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3500
# the best policy
#  [[0 3 1 1]
#  [0 0 1 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 5000/100000, Epsilon: 0.9500
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2100
# the best policy
#  [[2 3 1 1]
#  [0 0 1 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 6000/100000, Epsilon: 0.9400
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2400
# the best policy
#  [[2 3 1 1]
#  [0 0 1 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 7000/100000, Epsilon: 0.9300
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.1900
# the best policy
#  [[2 3 1 1]
#  [0 0 1 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 8000/100000, Epsilon: 0.9200
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3100
# the best policy
#  [[0 3 1 3]
#  [0 0 1 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 9000/100000, Epsilon: 0.9100
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2100
# the best policy
#  [[2 3 1 3]
#  [0 0 1 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 10000/100000, Epsilon: 0.9000
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3300
# the best policy
#  [[1 3 1 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 11000/100000, Epsilon: 0.8900
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2800
# the best policy
#  [[3 3 2 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 12000/100000, Epsilon: 0.8800
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2700
# the best policy
#  [[1 3 2 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 13000/100000, Epsilon: 0.8700
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.1700
# the best policy
#  [[2 3 2 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 14000/100000, Epsilon: 0.8600
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2500
# the best policy
#  [[0 1 2 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 15000/100000, Epsilon: 0.8500
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2900
# the best policy
#  [[2 3 2 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 16000/100000, Epsilon: 0.8400
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2600
# the best policy
#  [[2 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 17000/100000, Epsilon: 0.8300
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2900
# the best policy
#  [[2 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 18000/100000, Epsilon: 0.8200
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3600
# the best policy
#  [[1 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 19000/100000, Epsilon: 0.8100
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2600
# the best policy
#  [[1 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 20000/100000, Epsilon: 0.8000
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.1900
# the best policy
#  [[3 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 21000/100000, Epsilon: 0.7900
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2700
# the best policy
#  [[2 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 22000/100000, Epsilon: 0.7800
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2900
# the best policy
#  [[2 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 23000/100000, Epsilon: 0.7700
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2600
# the best policy
#  [[2 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 24000/100000, Epsilon: 0.7600
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3000
# the best policy
#  [[2 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 25000/100000, Epsilon: 0.7500
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3200
# the best policy
#  [[2 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 26000/100000, Epsilon: 0.7400
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3600
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 27000/100000, Epsilon: 0.7300
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2900
# the best policy
#  [[0 3 2 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 28000/100000, Epsilon: 0.7200
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2800
# the best policy
#  [[1 3 2 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 29000/100000, Epsilon: 0.7100
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2900
# the best policy
#  [[1 3 2 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 30000/100000, Epsilon: 0.7000
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2300
# the best policy
#  [[0 1 2 3]
#  [0 0 0 0]
#  [1 2 0 0]
#  [0 2 1 0]]
#
# Episode 31000/100000, Epsilon: 0.6900
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.1700
# the best policy
#  [[2 1 2 3]
#  [0 0 0 0]
#  [1 2 0 0]
#  [0 2 1 0]]
#
# Episode 32000/100000, Epsilon: 0.6800
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.1100
# the best policy
#  [[1 2 2 3]
#  [0 0 0 0]
#  [1 2 0 0]
#  [0 2 1 0]]
#
# Episode 33000/100000, Epsilon: 0.6700
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2000
# the best policy
#  [[2 3 2 3]
#  [0 0 0 0]
#  [1 2 0 0]
#  [0 2 1 0]]
#
# Episode 34000/100000, Epsilon: 0.6600
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.1200
# the best policy
#  [[2 3 1 3]
#  [0 0 0 0]
#  [1 2 0 0]
#  [0 2 1 0]]
#
# Episode 35000/100000, Epsilon: 0.6500
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.1300
# the best policy
#  [[1 3 1 3]
#  [0 0 0 0]
#  [1 2 0 0]
#  [0 2 1 0]]
#
# Episode 36000/100000, Epsilon: 0.6400
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2300
# the best policy
#  [[2 3 1 3]
#  [0 0 0 0]
#  [1 2 0 0]
#  [0 2 1 0]]
#
# Episode 37000/100000, Epsilon: 0.6300
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.1600
# the best policy
#  [[2 3 0 3]
#  [0 0 0 0]
#  [1 2 0 0]
#  [0 2 1 0]]
#
# Episode 38000/100000, Epsilon: 0.6200
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.1200
# the best policy
#  [[2 3 0 3]
#  [0 0 0 0]
#  [1 2 0 0]
#  [0 2 1 0]]
#
# Episode 39000/100000, Epsilon: 0.6100
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2100
# the best policy
#  [[1 3 0 3]
#  [0 0 0 0]
#  [1 2 0 0]
#  [0 2 1 0]]
#
# Episode 40000/100000, Epsilon: 0.6000
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.1700
# the best policy
#  [[3 3 0 3]
#  [0 0 0 0]
#  [1 2 0 0]
#  [0 2 1 0]]
#
# Episode 41000/100000, Epsilon: 0.5900
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.1500
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [1 2 0 0]
#  [0 2 1 0]]
#
# Episode 42000/100000, Epsilon: 0.5800
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3700
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 43000/100000, Epsilon: 0.5700
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3100
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 44000/100000, Epsilon: 0.5600
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3100
# the best policy
#  [[2 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 45000/100000, Epsilon: 0.5500
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3800
# the best policy
#  [[2 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 46000/100000, Epsilon: 0.5400
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2500
# the best policy
#  [[2 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 47000/100000, Epsilon: 0.5300
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3200
# the best policy
#  [[2 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 48000/100000, Epsilon: 0.5200
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2600
# the best policy
#  [[2 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 49000/100000, Epsilon: 0.5100
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2500
# the best policy
#  [[2 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 50000/100000, Epsilon: 0.5000
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2500
# the best policy
#  [[1 3 2 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 51000/100000, Epsilon: 0.4900
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.4000
# the best policy
#  [[0 3 2 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 52000/100000, Epsilon: 0.4800
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2200
# the best policy
#  [[2 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 53000/100000, Epsilon: 0.4700
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3600
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 54000/100000, Epsilon: 0.4600
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3000
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 55000/100000, Epsilon: 0.4500
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3300
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 56000/100000, Epsilon: 0.4400
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3500
# the best policy
#  [[2 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 57000/100000, Epsilon: 0.4300
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2500
# the best policy
#  [[2 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 58000/100000, Epsilon: 0.4200
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.1800
# the best policy
#  [[2 3 0 3]
#  [2 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 59000/100000, Epsilon: 0.4100
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3500
# the best policy
#  [[1 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 60000/100000, Epsilon: 0.4000
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2200
# the best policy
#  [[1 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 61000/100000, Epsilon: 0.3900
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2800
# the best policy
#  [[2 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 62000/100000, Epsilon: 0.3800
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3800
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 63000/100000, Epsilon: 0.3700
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2400
# the best policy
#  [[1 3 0 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 64000/100000, Epsilon: 0.3600
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3100
# the best policy
#  [[2 3 2 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 65000/100000, Epsilon: 0.3500
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2600
# the best policy
#  [[2 3 2 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 66000/100000, Epsilon: 0.3400
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2600
# the best policy
#  [[2 3 2 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 67000/100000, Epsilon: 0.3300
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2400
# the best policy
#  [[2 3 2 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 68000/100000, Epsilon: 0.3200
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2900
# the best policy
#  [[3 3 2 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 69000/100000, Epsilon: 0.3100
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3000
# the best policy
#  [[2 3 1 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 70000/100000, Epsilon: 0.3000
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.2600
# the best policy
#  [[0 3 1 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 71000/100000, Epsilon: 0.2900
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3300
# the best policy
#  [[0 3 1 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 72000/100000, Epsilon: 0.2800
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3100
# the best policy
#  [[2 3 1 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 73000/100000, Epsilon: 0.2700
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3500
# the best policy
#  [[2 3 1 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 74000/100000, Epsilon: 0.2600
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.3300
# the best policy
#  [[0 3 1 3]
#  [0 0 0 0]
#  [3 2 0 0]
#  [0 2 1 0]]
#
# Episode 75000/100000, Epsilon: 0.2500
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.7000
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 76000/100000, Epsilon: 0.2400
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.6400
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 77000/100000, Epsilon: 0.2300
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.7600
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 78000/100000, Epsilon: 0.2200
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.5200
# the best policy
#  [[1 3 0 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 79000/100000, Epsilon: 0.2100
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.5200
# the best policy
#  [[2 3 0 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 80000/100000, Epsilon: 0.2000
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.5300
# the best policy
#  [[2 3 0 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 81000/100000, Epsilon: 0.1900
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.7700
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 82000/100000, Epsilon: 0.1800
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.7500
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 83000/100000, Epsilon: 0.1700
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.8300
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 84000/100000, Epsilon: 0.1600
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.6500
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 85000/100000, Epsilon: 0.1500
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.6900
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 86000/100000, Epsilon: 0.1400
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.7500
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 87000/100000, Epsilon: 0.1300
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.7200
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 88000/100000, Epsilon: 0.1200
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.4900
# the best policy
#  [[1 3 0 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 89000/100000, Epsilon: 0.1100
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.5000
# the best policy
#  [[2 3 0 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 90000/100000, Epsilon: 0.1000
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.7800
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 91000/100000, Epsilon: 0.0900
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.7900
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 92000/100000, Epsilon: 0.0800
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.7800
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 93000/100000, Epsilon: 0.0700
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.6700
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 94000/100000, Epsilon: 0.0600
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.4700
# the best policy
#  [[2 3 0 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 95000/100000, Epsilon: 0.0500
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.7300
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 96000/100000, Epsilon: 0.0400
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.7300
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 97000/100000, Epsilon: 0.0300
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.7400
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 98000/100000, Epsilon: 0.0200
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.7600
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 99000/100000, Epsilon: 0.0100
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.7100
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
#
# Episode 100000/100000, Epsilon: 0.0100
# Evaluating learned policy...
# Average reward over 100 evaluation episodes: 0.7400
# the best policy
#  [[0 3 0 3]
#  [0 0 0 0]
#  [3 1 0 0]
#  [0 2 1 0]]
# the best policy:  [0 3 0 3 0 0 0 0 3 1 0 0 0 2 1 0]
